# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categories_df = pd.read_csv('../data/Kharis Grant Recipient Categories.csv')
categories_df.head()
# Out:
#           NAME OF CHARITY Food Insecurtiy Child Welfare Affordable Housing  \
# 0     F.P.C, Murfreesboro             NaN           NaN                NaN
# 1          Monroe Harding             NaN             T                NaN
# 2  Nashville Food Project               T           NaN                NaN
# 3    F.P. C., Clarksville             NaN           NaN                  T
# 4             Westminster             NaN           NaN                  T
#
#   Legacy
# 0      T
# 1    NaN
# 2    NaN
# 3      T
# 4    NaN

# %%
grants_df = pd.read_csv('../data/Chart of Grants.csv')
grants_df.head()
# Out:
#                Unnamed: 0 1/1/09 thru 6/30/09      2009 7/1/09 thru 6/30/10  \
# 0         NAME OF CHARITY             REQUEST   AWARDED             REQUEST
# 1                     NaN                 NaN       NaN                 NaN
# 2     F.P.C, Murfreesboro                 NaN  $10,000                  NaN
# 3          Monroe Harding                 NaN       NaN            $10,000
# 4  Nashville Food Project                 NaN       NaN            $10,000
#
#        2010  7/1/10 thru 6/30/11       2011 7/1/11 thru 6/30/12      2012  \
# 0   AWARDED              REQUEST    AWARDED             REQUEST   AWARDED
# 1       NaN                   NaN       NaN                 NaN       NaN
# 2       NaN                   NaN       NaN                 NaN       NaN
# 3  $10,000               $50,000   $25,000             $50,000   $25,000
# 4  $10,000               $15,000   $20,000                  NaN       NaN
#
# ...

# %%
grants_df.columns
# Out:
# Index(['Unnamed: 0', '1/1/09 thru 6/30/09', '2009', '7/1/09 thru 6/30/10',
#        '2010', ' 7/1/10 thru 6/30/11 ', '2011', '7/1/11 thru 6/30/12', '2012',
#        '7/1/12 thru 6/30/13', '2013', '7/1/13 thru 6/30/14', '2014',
#        '7/1/14 thru 6/30/15', '2015', '7/1/15 thru 6/30/16', '2016',
#        '7/1/16 thru 6/30/17', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 26', '2025', '2026', 'Unnamed: 29',
#        'Unnamed: 30'],
#       dtype='object')

# %%
grants_df = grants_df.drop(columns = ['1/1/09 thru 6/30/09','7/1/09 thru 6/30/10', ' 7/1/10 thru 6/30/11 ','7/1/11 thru 6/30/12', '7/1/12 thru 6/30/13', '7/1/13 thru 6/30/14', '7/1/14 thru 6/30/15', '7/1/15 thru 6/30/16', '7/1/16 thru 6/30/17', 'Unnamed: 26', 'Unnamed: 29', 'Unnamed: 30'])
grants_df.head()
# Out:
#                Unnamed: 0      2009      2010      2011      2012      2013  \
# 0         NAME OF CHARITY   AWARDED   AWARDED   AWARDED   AWARDED   AWARDED
# 1                     NaN       NaN       NaN       NaN       NaN       NaN
# 2     F.P.C, Murfreesboro  $10,000        NaN       NaN       NaN       NaN
# 3          Monroe Harding       NaN  $10,000   $25,000   $25,000   $30,000
# 4  Nashville Food Project       NaN  $10,000   $20,000        NaN       NaN
#
#        2014      2015      2016      2017     2018      2019      2020  \
# 0   AWARDED   AWARDED   AWARDED   AWARDED  AWARDED   AWARDED   AWARDED
# 1       NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 3  $30,000   $30,000   $35,000   $35,000       NaN       NaN       NaN
# 4       NaN  $15,000        NaN       NaN      NaN  $50,000   $50,000
#
#        2021 2022 2023 2024 2025 2026
# 0   AWARDED  NaN  NaN  NaN  NaN  NaN
# ...

# %%
grants_df.tail(10)
# Out:
#            Unnamed: 0      2009      2010       2011       2012       2013  \
# 95         Inspiritus       NaN       NaN        NaN        NaN        NaN
# 96   Endure Athletics       NaN       NaN        NaN        NaN        NaN
# 97        Park Center       NaN       NaN        NaN        NaN        NaN
# 98         The Branch       NaN       NaN        NaN        NaN        NaN
# 99                NaN       NaN       NaN        NaN        NaN        NaN
# 100               NaN       NaN       NaN        NaN        NaN        NaN
# 101               NaN       NaN       NaN        NaN        NaN        NaN
# 102               NaN       NaN       NaN        NaN        NaN        NaN
# 103               NaN       NaN       NaN        NaN        NaN        NaN
# 104       TOTAL GIVEN  $10,000   $20,000   $249,840   $359,840   $458,650
#
#             2014       2015       2016       2017       2018       2019  \
# ...

# %%
grants_df = grants_df.dropna(how='all')
grants_df.tail()
# Out:
#            Unnamed: 0      2009      2010       2011       2012       2013  \
# 95         Inspiritus       NaN       NaN        NaN        NaN        NaN
# 96   Endure Athletics       NaN       NaN        NaN        NaN        NaN
# 97        Park Center       NaN       NaN        NaN        NaN        NaN
# 98         The Branch       NaN       NaN        NaN        NaN        NaN
# 104       TOTAL GIVEN  $10,000   $20,000   $249,840   $359,840   $458,650
#
#             2014       2015       2016       2017       2018       2019  \
# 95           NaN        NaN        NaN        NaN        NaN        NaN
# 96           NaN        NaN        NaN        NaN        NaN        NaN
# 97           NaN        NaN        NaN        NaN        NaN        NaN
# 98           NaN        NaN        NaN        NaN        NaN        NaN
# 104  $682,650.00  $646,860   $656,700   $543,530   $576,168   $584,000
#
#           2020       2021       2022       2023       2024       2025  \
# ...

# %%
grants_df = grants_df.drop(0)
grants_df
# Out:
#                  Unnamed: 0      2009      2010       2011       2012  \
# 2       F.P.C, Murfreesboro  $10,000        NaN        NaN        NaN
# 3            Monroe Harding       NaN  $10,000    $25,000    $25,000
# 4    Nashville Food Project       NaN  $10,000    $20,000         NaN
# 5      F.P. C., Clarksville       NaN       NaN   $20,000    $10,000
# 6               Westminster       NaN       NaN   $20,000         NaN
# ..                      ...       ...       ...        ...        ...
# 95               Inspiritus       NaN       NaN        NaN        NaN
# 96         Endure Athletics       NaN       NaN        NaN        NaN
# 97              Park Center       NaN       NaN        NaN        NaN
# 98               The Branch       NaN       NaN        NaN        NaN
# 104             TOTAL GIVEN  $10,000   $20,000   $249,840   $359,840
#
#           2013         2014       2015       2016       2017       2018  \
# ...

# %%
grants_df.T
# Out:
#                             2               3                       4    \
# Unnamed: 0  F.P.C, Murfreesboro  Monroe Harding  Nashville Food Project
# 2009                   $10,000              NaN                     NaN
# 2010                        NaN        $10,000                 $10,000
# 2011                        NaN        $25,000                 $20,000
# 2012                        NaN        $25,000                      NaN
# 2013                        NaN        $30,000                      NaN
# 2014                        NaN        $30,000                      NaN
# 2015                        NaN        $30,000                 $15,000
# 2016                        NaN        $35,000                      NaN
# 2017                        NaN        $35,000                      NaN
# 2018                        NaN             NaN                     NaN
# 2019                        NaN             NaN                $50,000
# ...

# %%
mapping_dict = {'T': True, 'F': False}
categories_df['Food Insecurtiy'].fillna('F').map(mapping_dict).astype('bool')
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 92    False
# 93     True
# 94    False
# 95    False
# 96     True
# Name: Food Insecurtiy, Length: 97, dtype: bool

# %%
categories_df['Food Insecurtiy'] = categories_df['Food Insecurtiy'].fillna('F').map(mapping_dict).astype('bool')
categories_df['Child Welfare'] = categories_df['Child Welfare'].fillna('F').map(mapping_dict).astype('bool')
categories_df['Affordable Housing'] = categories_df['Affordable Housing'].fillna('F').map(mapping_dict).astype('bool')
categories_df['Legacy'] = categories_df['Legacy'].fillna('F').map(mapping_dict).astype('bool')
categories_df
# Out:
#            NAME OF CHARITY  Food Insecurtiy  Child Welfare  \
# 0      F.P.C, Murfreesboro            False          False
# 1           Monroe Harding            False           True
# 2   Nashville Food Project             True          False
# 3     F.P. C., Clarksville            False          False
# 4              Westminster            False          False
# ..                     ...              ...            ...
# 92       Sycamore Institue            False          False
# 93              Inspiritus             True          False
# 94        Endure Athletics            False           True
# 95             Park Center            False          False
# 96              The Branch             True          False
#
#     Affordable Housing  Legacy
# 0                False    True
# 1                False   False
# 2                False   False
# 3                 True    True
# 4                 True   False
# ..                 ...     ...
# ...

# %%
categories_df.loc[categories_df.Legacy & (categories_df['Food Insecurtiy']+categories_df['Child Welfare']+categories_df['Affordable Housing'] > 0)]
# Out:
#          NAME OF CHARITY  Food Insecurtiy  Child Welfare  Affordable Housing  \
# 3   F.P. C., Clarksville            False          False                True
# 62           BrightStone            False          False                True
#
#     Legacy
# 3     True
# 62    True

# %%
categories_df.at[3, 'Affordable Housing'] = False
categories_df.at[3, 'Affordable Housing']
# Out:
# np.False_

# %%
categories_df.at[62, 'Affordable Housing'] = False
categories_df.at[62, 'Affordable Housing']
# Out:
# np.False_

# %%
categories_df.loc[categories_df.Legacy & (categories_df['Food Insecurtiy']+categories_df['Child Welfare']+categories_df['Affordable Housing'] > 0)]
# Out:
# Empty DataFrame
# Columns: [NAME OF CHARITY, Food Insecurtiy, Child Welfare, Affordable Housing, Legacy, amount_of_categories]
# Index: []

# %%
categories_df[['Food Insecurtiy', 'Child Welfare', 'Affordable Housing']]
# Out:
#     Food Insecurtiy  Child Welfare  Affordable Housing
# 0             False          False               False
# 1             False           True               False
# 2              True          False               False
# 3             False          False               False
# 4             False          False                True
# ..              ...            ...                 ...
# 92            False          False                True
# 93             True          False                True
# 94            False           True               False
# 95            False          False                True
# 96             True          False               False
#
# [97 rows x 3 columns]

# %%
categories_df['amount_of_categories'] = categories_df[['Food Insecurtiy', 'Child Welfare', 'Affordable Housing']].sum(axis=1)
categories_df
# Out:
#            NAME OF CHARITY  Food Insecurtiy  Child Welfare  \
# 0      F.P.C, Murfreesboro            False          False
# 1           Monroe Harding            False           True
# 2   Nashville Food Project             True          False
# 3     F.P. C., Clarksville            False          False
# 4              Westminster            False          False
# ..                     ...              ...            ...
# 92       Sycamore Institue            False          False
# 93              Inspiritus             True          False
# 94        Endure Athletics            False           True
# 95             Park Center            False          False
# 96              The Branch             True          False
#
#     Affordable Housing  Legacy  amount_of_categories
# 0                False    True                     0
# 1                False   False                     1
# 2                False   False                     1
# ...

# %%
grants_df = grants_df.rename(columns = {'Unnamed: 0': 'name'})

# %%
grants_df_alt = grants_df.rename(columns = {'name': ''}).T
grants_df_alt
# Out:
#                       2               3                       4    \
#       F.P.C, Murfreesboro  Monroe Harding  Nashville Food Project
# 2009             $10,000              NaN                     NaN
# 2010                  NaN        $10,000                 $10,000
# 2011                  NaN        $25,000                 $20,000
# 2012                  NaN        $25,000                      NaN
# 2013                  NaN        $30,000                      NaN
# 2014                  NaN        $30,000                      NaN
# 2015                  NaN        $30,000                 $15,000
# 2016                  NaN        $35,000                      NaN
# 2017                  NaN        $35,000                      NaN
# 2018                  NaN             NaN                     NaN
# 2019                  NaN             NaN                $50,000
# 2020                  NaN             NaN                $50,000
# ...

# %%
grants_df_alt.columns = grants_df_alt.iloc[0]
grants_df_alt
# Out:
#       F.P.C, Murfreesboro  Monroe Harding  Nashville Food Project  \
#       F.P.C, Murfreesboro  Monroe Harding  Nashville Food Project
# 2009             $10,000              NaN                     NaN
# 2010                  NaN        $10,000                 $10,000
# 2011                  NaN        $25,000                 $20,000
# 2012                  NaN        $25,000                      NaN
# 2013                  NaN        $30,000                      NaN
# 2014                  NaN        $30,000                      NaN
# 2015                  NaN        $30,000                 $15,000
# 2016                  NaN        $35,000                      NaN
# 2017                  NaN        $35,000                      NaN
# 2018                  NaN             NaN                     NaN
# 2019                  NaN             NaN                $50,000
# 2020                  NaN             NaN                $50,000
# ...

# %%
grants_df_alt = grants_df_alt.drop(grants_df_alt.index[0])
grants_df_alt
# Out:
#      F.P.C, Murfreesboro Monroe Harding Nashville Food Project  \
# 2009            $10,000             NaN                    NaN
# 2010                 NaN       $10,000                $10,000
# 2011                 NaN       $25,000                $20,000
# 2012                 NaN       $25,000                     NaN
# 2013                 NaN       $30,000                     NaN
# 2014                 NaN       $30,000                     NaN
# 2015                 NaN       $30,000                $15,000
# 2016                 NaN       $35,000                     NaN
# 2017                 NaN       $35,000                     NaN
# 2018                 NaN            NaN                    NaN
# 2019                 NaN            NaN               $50,000
# 2020                 NaN            NaN               $50,000
# 2021                 NaN            NaN               $50,000
# 2022                 NaN            NaN                    NaN
# ...
