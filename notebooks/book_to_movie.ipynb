# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup as BS
import re

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(0–9,_A–C)'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64'}

response = requests.get(URL, headers = headers)

# %%
response.status_code
# Out:
# 200

# %%
tables = pd.read_html(response.content, flavor='bs4', attrs = {'class': 'wikitable'})

# %%
tables
# Out:
# [                                     Fiction work(s)  \
#  0                The 25th Hour (2001), David Benioff
#  1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
#  2       4.50 from Paddington (1957), Agatha Christie
#  3       4.50 from Paddington (1957), Agatha Christie
#  4                    58 Minutes (1987), Walter Wager
#  5  69 (シクスティナイン, Shikusutinain) (1987), Ryu Murakami
#
#                                    Film adaptation(s)
#  0                                   25th Hour (2002)
#  1                                 Grasshopper (2015)
#  2                            Murder, She Said (1961)
#  3  Crime Is Our Business (French: Le Crime est no...
#  4                                  Die Hard 2 (1990)
#  5                                          69 (2004)  ,
#                                         Fiction work(s)  \
#  0           The A.B.C. Murders (1936), Agatha Christie
#  1              À ton image (1998), Louise L. Lambrichs
# ...

# %%
list_1 = pd.concat(tables).reset_index(drop = True)
list_1
# Out:
#                                        Fiction work(s)  \
# 0                  The 25th Hour (2001), David Benioff
# 1    3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2         4.50 from Paddington (1957), Agatha Christie
# 3         4.50 from Paddington (1957), Agatha Christie
# 4                      58 Minutes (1987), Walter Wager
# ..                                                 ...
# 727  Cry Wolf (a. k. a. The Demarest Inheritance) (...
# 728           Cutter and Bone (1976), Newton Thornburg
# 729                       Cyborg (1972), Martin Caidin
# 730         Cycle of the Werewolf (1983), Stephen King
# 731  The Cypher (a. k. a. The Cipher) (1961), Gordo...
#
#                                     Film adaptation(s)
# 0                                     25th Hour (2002)
# 1                                   Grasshopper (2015)
# 2                              Murder, She Said (1961)
# 3    Crime Is Our Business (French: Le Crime est no...
# ...

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(D–J)'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64'}

response = requests.get(URL, headers = headers)
response.status_code
# Out:
# 200

# %%
tables = pd.read_html(response.content, flavor='bs4', attrs = {'class': 'wikitable'})
tables
# Out:
# [                           Fiction work(s)        Film adaptation(s)
#  0      The Da Vinci Code (2003), Dan Brown  The Da Vinci Code (2006)
#  1              Dad (1981), William Wharton                Dad (1989)
#  2            Damage (1991), Josephine Hart             Damage (1992)
#  3    Damnation Alley (1967), Roger Zelazny    Damnation Alley (1977)
#  4       The Damned Utd (2006), David Peace  The Damned United (2009)
#  ..                                     ...                       ...
#  337             Dune (1965), Frank Herbert               Dune (1984)
#  338             Dune (1965), Frank Herbert     Dune: Part One (2021)
#  339             Dune (1965), Frank Herbert     Dune: Part Two (2024)
#  340   The Dying Animal (2001), Philip Roth              Elegy (2008)
#  341     Dying Young (1990), Marti Leimbach        Dying Young (1991)
#
#  [342 rows x 2 columns],
#                                        Fiction work(s)  \
# ...

# %%
list_2 = pd.concat(tables).reset_index(drop = True)
list_2
# Out:
#                              Fiction work(s)  \
# 0        The Da Vinci Code (2003), Dan Brown
# 1                Dad (1981), William Wharton
# 2              Damage (1991), Josephine Hart
# 3      Damnation Alley (1967), Roger Zelazny
# 4         The Damned Utd (2006), David Peace
# ...                                      ...
# 1152  Jurassic Park (1990), Michael Crichton
# 1153  Jurassic Park (1990), Michael Crichton
# 1154  Jurassic Park (1990), Michael Crichton
# 1155  Jurassic Park (1990), Michael Crichton
# 1156        Justine (1957), Lawrence Durrell
#
#                          Film adaptation(s)
# 0                  The Da Vinci Code (2006)
# 1                                Dad (1989)
# 2                             Damage (1992)
# 3                    Damnation Alley (1977)
# 4                  The Damned United (2009)
# ...                                     ...
# 1152                  Jurassic World (2015)
# 1153  Jurassic World: Fallen Kingdom (2018)
# ...

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(K-R)'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64'}

response = requests.get(URL, headers = headers)
response.status_code
# Out:
# 200

# %%
tables = pd.read_html(response.content, flavor='bs4', attrs = {'class': 'wikitable'})
tables
# Out:
# [                                      Fiction work(s)  \
#  0                Kami no Tsuki (2012), Mitsuyo Kakuta
#  1                 Kenka erejii (1963), Takashi Suzuki
#  2       The Key (鍵, Kagi) (1956), Jun'ichirō Tanizaki
#  3       The Key (鍵, Kagi) (1956), Jun'ichirō Tanizaki
#  4       The Key (鍵, Kagi) (1956), Jun'ichirō Tanizaki
#  5        The Keys of the Kingdom (1941), A. J. Cronin
#  6            Kidnapped (1886), Robert Louis Stevenson
#  7            Kidnapped (1886), Robert Louis Stevenson
#  8            Kidnapped (1886), Robert Louis Stevenson
#  9            Kidnapped (1886), Robert Louis Stevenson
#  10           Kidnapped (1886), Robert Louis Stevenson
#  11           Kidnapped (1886), Robert Louis Stevenson
#  12  King Solomon's Mines (1885), Sir H. Rider Haggard
#  13  King Solomon's Mines (1885), Sir H. Rider Haggard
#  14  King Solomon's Mines (1885), Sir H. Rider Haggard
#  15  King Solomon's Mines (1885), Sir H. Rider Haggard
# ...

# %%
list_3 = pd.concat(tables).reset_index(drop = True)
list_3
# Out:
#                                        Fiction work(s)  \
# 0                 Kami no Tsuki (2012), Mitsuyo Kakuta
# 1                  Kenka erejii (1963), Takashi Suzuki
# 2        The Key (鍵, Kagi) (1956), Jun'ichirō Tanizaki
# 3        The Key (鍵, Kagi) (1956), Jun'ichirō Tanizaki
# 4        The Key (鍵, Kagi) (1956), Jun'ichirō Tanizaki
# ..                                                 ...
# 933  A Running Duck (a.k.a. Fair Game) (1974), Paul...
# 934  A Running Duck (a.k.a. Fair Game) (1974), Paul...
# 935         The Running Man (1982), Stephen King[N 34]
# 936         The Running Man (1982), Stephen King[N 34]
# 937             The Russia House (1989), John le Carré
#
#                       Film adaptation(s)
# 0                       Pale Moon (2014)
# 1                  Fighting Elegy (1966)
# 2                   Odd Obsession (1959)
# 3    The Key (Italian: La chiave) (1983)
# 4                         The Key (2014)
# ..                                   ...
# ...

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(S-Z)'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64'}

response = requests.get(URL, headers = headers)
response.status_code
# Out:
# 200

# %%
tables = pd.read_html(response.content, flavor='bs4', attrs = {'class': 'wikitable'})
tables
# Out:
# [                                       Fiction work(s)  \
#  0                   Sackett (1961)[N 1], Louis L'Amour
#  1    Sacred Wood (Chinese: 神木 Shen Mu) (1999), Liu ...
#  2       The Saga of Pecos Bill (1923), Edward O'Reilly
#  3       The Saga of Pecos Bill (1923), Edward O'Reilly
#  4                         Sahara (1992), Clive Cussler
#  ..                                                 ...
#  250  The Swiss Family Robinson (French: Der Schweiz...
#  251  The Swiss Family Robinson (French: Der Schweiz...
#  252  The Swiss Family Robinson (French: Der Schweiz...
#  253  The Swiss Family Robinson (French: Der Schweiz...
#  254         The Sword in the Stone (1938), T. H. White
#
#                                      Film adaptation(s)
#  0                             The Sacketts (1979)[N 2]
#  1    Blind Shaft (Chinese: 盲井; pinyin: Mángjǐng) (2...
#  2                                   Melody Time (1948)
#  3                                     Tall Tale (1995)
# ...

# %%
list_4 = pd.concat(tables).reset_index(drop = True)
list_4
# Out:
#                                        Fiction work(s)  \
# 0                   Sackett (1961)[N 1], Louis L'Amour
# 1    Sacred Wood (Chinese: 神木 Shen Mu) (1999), Liu ...
# 2       The Saga of Pecos Bill (1923), Edward O'Reilly
# 3       The Saga of Pecos Bill (1923), Edward O'Reilly
# 4                         Sahara (1992), Clive Cussler
# ..                                                 ...
# 842  Zazie in the Metro (French: Zazie dans le métr...
# 843  Zero Focus (雪国, Zero no Shōten) (1959), Seichō...
# 844  Zift (Bulgarian: Дзифт, Dzift) (2006), Vladisl...
# 845               Zona Zamfirova (1906), Stefan Sremac
# 846          Zorba the Greek (1946), Nikos Kazantzakis
#
#                                     Film adaptation(s)
# 0                             The Sacketts (1979)[N 2]
# 1    Blind Shaft (Chinese: 盲井; pinyin: Mángjǐng) (2...
# 2                                   Melody Time (1948)
# 3                                     Tall Tale (1995)
# ...

# %%
list_raw = pd.concat([list_1, list_2, list_3, list_4]).reset_index(drop = True)
list_raw
# Out:
#                                         Fiction work(s)  \
# 0                   The 25th Hour (2001), David Benioff
# 1     3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2          4.50 from Paddington (1957), Agatha Christie
# 3          4.50 from Paddington (1957), Agatha Christie
# 4                       58 Minutes (1987), Walter Wager
# ...                                                 ...
# 3669  Zazie in the Metro (French: Zazie dans le métr...
# 3670  Zero Focus (雪国, Zero no Shōten) (1959), Seichō...
# 3671  Zift (Bulgarian: Дзифт, Dzift) (2006), Vladisl...
# 3672               Zona Zamfirova (1906), Stefan Sremac
# 3673          Zorba the Greek (1946), Nikos Kazantzakis
#
#                                      Film adaptation(s)
# 0                                      25th Hour (2002)
# 1                                    Grasshopper (2015)
# 2                               Murder, She Said (1961)
# 3     Crime Is Our Business (French: Le Crime est no...
# ...

# %%
list_raw.iloc[1]['Fiction work(s)']
# Out:
# '3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōtarō Isaka'

# %%
re.search(r'(.*)\(\d{4}', '3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōtarō Isaka').group(1).strip().title()
# Out:
# '3 Assassins (グラスホッパー, Gurasuhoppā)'

# %%
re.search(r'\((\d{4})\)', '3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōtarō Isaka').group(1).strip().title()
# Out:
# '2004'

# %%
re.search(r'\(\d{4}\),(.*)', '3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōtarō Isaka').group(1).strip().title()
# Out:
# 'Kōtarō Isaka'

# %%
re.search(r'[\)\]],(.*)', 'Winnie-the-Pooh (1926–1928) (series)[N 18], A.A. Milne').group(1).strip().title()
# Out:
# 'A.A. Milne'

# %%
re.search(r'(.*)\(\d{4}\)', list_raw.iloc[1]['Fiction work(s)']).group(1).strip().title()
# Out:
# '3 Assassins (グラスホッパー, Gurasuhoppā)'

# %%
re.search(r'\((\d{4})\)', 'Winnie-the-Pooh (1926–1928) (series)[N 18], A.A. Milne')

# %%
no_match = re.search(r'\(\d{4}\)', 'Winnie-the-Pooh (1926–1928) (series)[N 18], A.A. Milne')
no_match

# %%
re.search(r'\(series\)', 'Winnie-the-Pooh (1926–1928) (series)[N 18], A.A. Milne')
# Out:
# <re.Match object; span=(28, 36), match='(series)'>

# %%
re.sub(r'\[.*]', '', 'Winnie-the-Pooh (1926–1928) (series)[N 18], A.A. Milne')
# Out:
# 'Winnie-the-Pooh (1926–1928) (series), A.A. Milne'

# %%
for ind, row in list_raw.iterrows():
    if re.search(r'[\)\]],(.*)', row['Fiction work(s)']) is None:
        print('error')
        print(ind)
    else:
        print(re.search(r'[\)\]],(.*)', row['Fiction work(s)']).group(1).strip().title())
        print(ind)
# Out:
# David Benioff
# 0
# Kōtarō Isaka
# 1
# Agatha Christie
# 2
# Agatha Christie
# 3
# Walter Wager
# 4
# Ryu Murakami
# 5
# Agatha Christie
# 6
# Louise L. Lambrichs
# 7
# Nick Hornby
# 8
# Louis Begley
# 9
# David Baldacci
# 10
# Anne Tyler
# 11
# Wally Ferris
# 12
# Yoram Kaniuk
# 13
# Sean Desmond
# 14
# Joe David Brown
# 15
# Jin Renshun
# 16
# Benjamin Constant
# 17
# Jack London
# 18
# Harold Robbins
# 19
# Arturo Pérez-Reverte
# 20
# Jules Verne
# 21
# James Justinian Morier
# 22
# Mark Twain
# 23
# Mark Twain
# 24
# Mark Twain
# 25
# Mark Twain
# 26
# Mark Twain
# 27
# Mark Twain
# 28
# Mark Twain
# 29
# Mark Twain
# 30
# Mark Twain
# 31
# Mark Twain
# 32
# Mark Twain
# 33
# Mark Twain
# 34
# Mark Twain
# 35
# Carlo Collodi
# 36
# Carlo Collodi
# 37
# Carlo Collodi
# 38
# Carlo Collodi
# 39
# Carlo Collodi
# 40
# Carlo Collodi
# 41
# Carlo Collodi
# 42
# Carlo Collodi
# 43
# Carlo Collodi
# 44
# Carlo Collodi
# 45
# Carlo Collodi
# 46
# Carlo Collodi
# 47
# Carlo Collodi
# 48
# ...

# %%
list_raw.iloc[2468]['Fiction work(s)']
# Out:
# 'One Thousand and One Nights (Arabic: أَلْفُ لَيْلَةٍ وَلَيْلَةٌ ʾAlf Laylah wa-Laylah)[N 26]'

# %%
list_raw
# Out:
#                                         Fiction work(s)  \
# 0                   The 25th Hour (2001), David Benioff
# 1     3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2          4.50 from Paddington (1957), Agatha Christie
# 3          4.50 from Paddington (1957), Agatha Christie
# 4                       58 Minutes (1987), Walter Wager
# ...                                                 ...
# 3669  Zazie in the Metro (French: Zazie dans le métr...
# 3670  Zero Focus (雪国, Zero no Shōten) (1959), Seichō...
# 3671  Zift (Bulgarian: Дзифт, Dzift) (2006), Vladisl...
# 3672               Zona Zamfirova (1906), Stefan Sremac
# 3673          Zorba the Greek (1946), Nikos Kazantzakis
#
#                                      Film adaptation(s)
# 0                                      25th Hour (2002)
# 1                                    Grasshopper (2015)
# 2                               Murder, She Said (1961)
# 3     Crime Is Our Business (French: Le Crime est no...
# ...

# %%
list_raw['Book_Title'] = ''
list_raw['Publication_Date'] = ''
list_raw['Author'] = ''

# %%
list_raw.head(1)
# Out:
#                        Fiction work(s) Film adaptation(s) Author Book_Title  \
# 0  The 25th Hour (2001), David Benioff   25th Hour (2002)
#
#   Publication_Date
# 0

# %%
for ind, row in list_raw.iterrows():
    list_raw.loc[ind, 'Fiction work(s)'] = re.sub(r'\[.*]', '', row['Fiction work(s)'])
    if re.search(r'(.*)\(\d{4}', row['Fiction work(s)']) is None:
       list_raw.loc[ind, 'Book_Title'] = 'unknown'
    else:
        list_raw.loc[ind, 'Book_Title'] = re.search(r'(.*)\(\d{4}', row['Fiction work(s)']).group(1).strip().title()

# %%
list_raw.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s) Author  \
# 0                                   25th Hour (2002)
# 1                                 Grasshopper (2015)
# 2                            Murder, She Said (1961)
# 3  Crime Is Our Business (French: Le Crime est no...
# 4                                  Die Hard 2 (1990)
#
#                            Book_Title Publication_Date
# 0                       The 25Th Hour
# 1  3 Assassins (グラスホッパー, Gurasuhoppā)
# 2                4.50 From Paddington
# 3                4.50 From Paddington
# 4                          58 Minutes

# %%
for ind, row in list_raw.iterrows():
    if re.search(r'\((\d{4})', row['Fiction work(s)']) is None:
       list_raw.loc[ind, 'Publication_Date'] = 'unknown'
    else:
        list_raw.loc[ind, 'Publication_Date'] = re.search(r'\((\d{4})', row['Fiction work(s)']).group(1).strip().title()

# %%
list_raw.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s) Author  \
# 0                                   25th Hour (2002)
# 1                                 Grasshopper (2015)
# 2                            Murder, She Said (1961)
# 3  Crime Is Our Business (French: Le Crime est no...
# 4                                  Die Hard 2 (1990)
#
#                            Book_Title Publication_Date
# 0                       The 25Th Hour             2001
# 1  3 Assassins (グラスホッパー, Gurasuhoppā)             2004
# 2                4.50 From Paddington             1957
# 3                4.50 From Paddington             1957
# ...

# %%
for ind, row in list_raw.iterrows():
    if re.search(r'[\)\]],(.*)', row['Fiction work(s)']) is None:
       list_raw.loc[ind, 'Author'] = 'unknown'
    else:
        list_raw.loc[ind, 'Author'] = re.search(r'[\)\]],(.*)', row['Fiction work(s)']).group(1).strip().title()

# %%
list_raw.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s)           Author  \
# 0                                   25th Hour (2002)    David Benioff
# 1                                 Grasshopper (2015)     Kōtarō Isaka
# 2                            Murder, She Said (1961)  Agatha Christie
# 3  Crime Is Our Business (French: Le Crime est no...  Agatha Christie
# 4                                  Die Hard 2 (1990)     Walter Wager
#
#                            Book_Title Publication_Date
# 0                       The 25Th Hour             2001
# 1  3 Assassins (グラスホッパー, Gurasuhoppā)             2004
# 2                4.50 From Paddington             1957
# ...

# %%
list_raw['Book_Title_Cleaned'] = ''
list_raw['Film_Title'] = ''
list_raw['Release_Date'] = ''

# %%
re.search(r'(.*)\(', '3 Assassins (グラスホッパー, Gurasuhoppā)').group(1).strip().title()
# Out:
# '3 Assassins'

# %%
for ind, row in list_raw.iterrows():
    if re.search(r'(.*)\(', row['Book_Title']) is None:
       list_raw.loc[ind, 'Book_Title_Cleaned'] = row['Book_Title']
    else:
        list_raw.loc[ind, 'Book_Title_Cleaned'] = re.search(r'(.*)\(', row['Book_Title']).group(1).strip().title()

# %%
list_raw.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s)           Author  \
# 0                                   25th Hour (2002)    David Benioff
# 1                                 Grasshopper (2015)     Kōtarō Isaka
# 2                            Murder, She Said (1961)  Agatha Christie
# 3  Crime Is Our Business (French: Le Crime est no...  Agatha Christie
# 4                                  Die Hard 2 (1990)     Walter Wager
#
#                            Book_Title Publication_Date    Book_Title_Cleaned  \
# 0                       The 25Th Hour             2001         The 25Th Hour
# ...

# %%
list_raw.iloc[2561]['Film adaptation(s)']
# Out:
# nan

# %%
list_raw.iloc[2561:2580]
# Out:
#                                      Fiction work(s)  \
# 2561  The Picture of Dorian Gray (1890), Oscar Wilde
# 2562  The Picture of Dorian Gray (1890), Oscar Wilde
# 2563  The Picture of Dorian Gray (1890), Oscar Wilde
# 2564  The Picture of Dorian Gray (1890), Oscar Wilde
# 2565  The Picture of Dorian Gray (1890), Oscar Wilde
# 2566  The Picture of Dorian Gray (1890), Oscar Wilde
# 2567  The Picture of Dorian Gray (1890), Oscar Wilde
# 2568  The Picture of Dorian Gray (1890), Oscar Wilde
# 2569  The Picture of Dorian Gray (1890), Oscar Wilde
# 2570  The Picture of Dorian Gray (1890), Oscar Wilde
# 2571  The Picture of Dorian Gray (1890), Oscar Wilde
# 2572  The Picture of Dorian Gray (1890), Oscar Wilde
# 2573  The Picture of Dorian Gray (1890), Oscar Wilde
# 2574  The Picture of Dorian Gray (1890), Oscar Wilde
# 2575  The Picture of Dorian Gray (1890), Oscar Wilde
# 2576  The Picture of Dorian Gray (1890), Oscar Wilde
# 2577      The Pillar of Light (1990), Gerald N. Lund
# ...

# %%
list_raw = list_raw.drop(index=2561)
list_raw.iloc[2561]
# Out:
# Fiction work(s)       The Picture of Dorian Gray (1890), Oscar Wilde
# Film adaptation(s)                 The Picture of Dorian Gray (1916)
# Author                                                   Oscar Wilde
# Book_Title                                The Picture Of Dorian Gray
# Publication_Date                                                1890
# Book_Title_Cleaned                        The Picture Of Dorian Gray
# Film_Title
# Release_Date
# Name: 2562, dtype: object

# %%
list_raw = list_raw.reset_index(drop = True)
list_raw.shape
# Out:
# (3673, 8)

# %%
list_raw.iloc[2624:2634]
# Out:
#                                    Fiction work(s)  \
# 2624  The Prince and the Pauper (1881), Mark Twain
# 2625  The Prince and the Pauper (1881), Mark Twain
# 2626  The Prince and the Pauper (1881), Mark Twain
# 2627  The Prince and the Pauper (1881), Mark Twain
# 2628  The Prince and the Pauper (1881), Mark Twain
# 2629  The Prince and the Pauper (1881), Mark Twain
# 2630  The Prince and the Pauper (1881), Mark Twain
# 2631  The Prince and the Pauper (1881), Mark Twain
# 2632  The Prince and the Pauper (1881), Mark Twain
# 2633  The Prince and the Pauper (1881), Mark Twain
#
#                                      Film adaptation(s)      Author  \
# 2624                                                NaN  Mark Twain
# 2625                   The Prince and the Pauper (1915)  Mark Twain
# 2626  The Prince and the Pauper (German: Der Prinz u...  Mark Twain
# 2627                   The Prince and the Pauper (1937)  Mark Twain
# ...

# %%
list_raw = list_raw.drop(index=2624).reset_index(drop = True)
list_raw.iloc[2624]
# Out:
# Fiction work(s)       The Prince and the Pauper (1881), Mark Twain
# Film adaptation(s)                The Prince and the Pauper (1915)
# Author                                                  Mark Twain
# Book_Title                               The Prince And The Pauper
# Publication_Date                                              1881
# Book_Title_Cleaned                       The Prince And The Pauper
# Film_Title
# Release_Date
# Name: 2624, dtype: object

# %%
list_raw.iloc[3196:3200]
# Out:
#                                         Fiction work(s)  \
# 3196  The Three Musketeers (French: Les Trois Mousqu...
# 3197  The Three Musketeers (French: Les Trois Mousqu...
# 3198  The Three Musketeers (French: Les Trois Mousqu...
# 3199  The Three Musketeers (French: Les Trois Mousqu...
#
#                        Film adaptation(s)                 Author  \
# 3196                                  NaN  Alexandre Dumas, Père
# 3197          The Three Musketeers (1914)  Alexandre Dumas, Père
# 3198          The Three Musketeers (1916)  Alexandre Dumas, Père
# 3199  The Three Musketeers (1921; French)  Alexandre Dumas, Père
#
#                                              Book_Title Publication_Date  \
# 3196  The Three Musketeers (French: Les Trois Mousqu...             1844
# 3197  The Three Musketeers (French: Les Trois Mousqu...             1844
# 3198  The Three Musketeers (French: Les Trois Mousqu...             1844
# ...

# %%
list_raw = list_raw.drop(index=3196).reset_index(drop = True)
list_raw.iloc[3195:3197]
# Out:
#                                         Fiction work(s)  \
# 3195         The Three Godfathers (1913), Peter B. Kyne
# 3196  The Three Musketeers (French: Les Trois Mousqu...
#
#                Film adaptation(s)                 Author  \
# 3195     The Godchild (1974)[N 2]          Peter B. Kyne
# 3196  The Three Musketeers (1914)  Alexandre Dumas, Père
#
#                                              Book_Title Publication_Date  \
# 3195                               The Three Godfathers             1913
# 3196  The Three Musketeers (French: Les Trois Mousqu...             1844
#
#         Book_Title_Cleaned Film_Title Release_Date
# 3195  The Three Godfathers
# 3196  The Three Musketeers

# %%
for ind, row in list_raw.iterrows():
    if re.search(r'(.*)\(\d{4}', row['Film adaptation(s)']) is None:
        print('error')
        print(ind)
    else:
        print(re.search(r'(.*)\(\d{4}', row['Film adaptation(s)']).group(1).strip().title())
        print(ind)
# Out:
# 25Th Hour
# 0
# Grasshopper
# 1
# Murder, She Said
# 2
# Crime Is Our Business (French: Le Crime Est Notre Affaire)
# 3
# Die Hard 2
# 4
# 69
# 5
# The Alphabet Murders
# 6
# À Ton Image
# 7
# About A Boy
# 8
# About Schmidt
# 9
# Absolute Power
# 10
# The Accidental Tourist
# 11
# Across 110Th Street
# 12
# Adam Resurrected
# 13
# Abandon
# 14
# Paper Moon
# 15
# Green Tea
# 16
# Adolphe
# 17
# Adventure
# 18
# The Adventurers
# 19
# Alatriste
# 20
# The Conquest Of The Pole (French: Conquête Du Pôle)
# 21
# The Adventures Of Hajji Baba
# 22
# Huckleberry Finn
# 23
# Huckleberry Finn
# 24
# Huck Finn
# 25
# The Adventures Of Huckleberry Finn
# 26
# The Adventures Of Huckleberry Finn
# 27
# The Adventures Of Huckleberry Finn
# 28
# Huckleberry Finn
# 29
# Hopelessly Lost
# 30
# Huckleberry Finn
# 31
# The Adventures Of Huckleberry Finn
# 32
# Adventures Of Huckleberry Finn
# 33
# The Adventures Of Huck Finn
# 34
# Tom And Huck
# 35
# The Adventures Of Pinocchio
# 36
# ...

# %%
list_raw.at[2202, 'Film adaptation(s)'] = 'The Actor (2025)'
list_raw.at[2202, 'Film adaptation(s)']
# Out:
# 'The Actor (2025)'

# %%
for ind, row in list_raw.iterrows():
    list_raw.loc[ind, 'Film adaptation(s)'] = re.sub(r'\[.*]', '', row['Film adaptation(s)'])
    if re.search(r'(.*)\(\d{4}', row['Film adaptation(s)']) is None:
       list_raw.loc[ind, 'Film_Title'] = 'unknown'
    else:
        list_raw.loc[ind, 'Film_Title'] = re.search(r'(.*)\(\d{4}', row['Film adaptation(s)']).group(1).strip().title()

# %%
list_raw
# Out:
#                                         Fiction work(s)  \
# 0                   The 25th Hour (2001), David Benioff
# 1     3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2          4.50 from Paddington (1957), Agatha Christie
# 3          4.50 from Paddington (1957), Agatha Christie
# 4                       58 Minutes (1987), Walter Wager
# ...                                                 ...
# 3666  Zazie in the Metro (French: Zazie dans le métr...
# 3667  Zero Focus (雪国, Zero no Shōten) (1959), Seichō...
# 3668  Zift (Bulgarian: Дзифт, Dzift) (2006), Vladisl...
# 3669               Zona Zamfirova (1906), Stefan Sremac
# 3670          Zorba the Greek (1946), Nikos Kazantzakis
#
#                                      Film adaptation(s)             Author  \
# 0                                      25th Hour (2002)      David Benioff
# 1                                    Grasshopper (2015)       Kōtarō Isaka
# ...

# %%
re.search(r'\((\d{4})', 'Don Quixote (1933; French)')
# Out:
# <re.Match object; span=(12, 17), match='(1933'>

# %%
for ind, row in list_raw.iterrows():
    if re.search(r'\((\d{4})', row['Film adaptation(s)']) is None:
       list_raw.loc[ind, 'Release_Date'] = 'unknown'
    else:
        list_raw.loc[ind, 'Release_Date'] = re.search(r'\((\d{4})', row['Film adaptation(s)']).group(1).strip().title()

# %%
list_raw
# Out:
#                                         Fiction work(s)  \
# 0                   The 25th Hour (2001), David Benioff
# 1     3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2          4.50 from Paddington (1957), Agatha Christie
# 3          4.50 from Paddington (1957), Agatha Christie
# 4                       58 Minutes (1987), Walter Wager
# ...                                                 ...
# 3666  Zazie in the Metro (French: Zazie dans le métr...
# 3667  Zero Focus (雪国, Zero no Shōten) (1959), Seichō...
# 3668  Zift (Bulgarian: Дзифт, Dzift) (2006), Vladisl...
# 3669               Zona Zamfirova (1906), Stefan Sremac
# 3670          Zorba the Greek (1946), Nikos Kazantzakis
#
#                                      Film adaptation(s)             Author  \
# 0                                      25th Hour (2002)      David Benioff
# 1                                    Grasshopper (2015)       Kōtarō Isaka
# ...

# %%
list_raw.to_csv('../data/list_raw.csv')

# %%
list_raw.loc[list_raw.Release_Date == 'unknown']
# Out:
#                                         Fiction work(s) Film adaptation(s)  \
# 196        Anne of Avonlea (1909), Lucy Maud Montgomery      same as below
# 205   Anne of Windy Poplars (1936), Lucy Maud Montgo...      same as above
# 322                       Beau Ideal (1927), P. C. Wren      same as above
# 323                     Beau Sabreur (1926), P. C. Wren      same as above
# 487   The Brave Little Toaster Goes to Mars (1988), ...      same as above
# 776   Day with a Perfect Stranger (2006), David Gregory      same as below
# 2671                     Psycho II (1982), Robert Bloch      same as above
# 2916          Shaft's Big Score! (1972), Ernest Tidyman      same as above
#
#                     Author                             Book_Title  \
# 196   Lucy Maud Montgomery                        Anne Of Avonlea
# 205   Lucy Maud Montgomery                  Anne Of Windy Poplars
# 322             P. C. Wren                             Beau Ideal
# ...

# %%
list_raw.loc[((list_raw['Film adaptation(s)'] == 'same as below') | (list_raw['Film adaptation(s)'] == 'same as above'))]
# Out:
#                                         Fiction work(s) Film adaptation(s)  \
# 196        Anne of Avonlea (1909), Lucy Maud Montgomery      same as below
# 205   Anne of Windy Poplars (1936), Lucy Maud Montgo...      same as above
# 322                       Beau Ideal (1927), P. C. Wren      same as above
# 323                     Beau Sabreur (1926), P. C. Wren      same as above
# 487   The Brave Little Toaster Goes to Mars (1988), ...      same as above
# 776   Day with a Perfect Stranger (2006), David Gregory      same as below
# 2671                     Psycho II (1982), Robert Bloch      same as above
# 2916          Shaft's Big Score! (1972), Ernest Tidyman      same as above
#
#                     Author                             Book_Title  \
# 196   Lucy Maud Montgomery                        Anne Of Avonlea
# 205   Lucy Maud Montgomery                  Anne Of Windy Poplars
# 322             P. C. Wren                             Beau Ideal
# ...

# %%
the_list = list_raw[~((list_raw['Film adaptation(s)'] == 'same as below') | (list_raw['Film adaptation(s)'] == 'same as above'))]

# %%
the_list.Release_Date = the_list.Release_Date.astype(int)
# Out:
# C:\Users\erics\AppData\Local\Temp\ipykernel_32080\3346757667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   the_list.Release_Date = the_list.Release_Date.astype(int)

# %%
the_list = the_list[~(the_list.Publication_Date == 'unknown')]
the_list.shape
# Out:
# (3434, 8)

# %%
the_list = the_list[the_list.Release_Date > 2000]
the_list.shape
# Out:
# (755, 8)

# %%
the_list.Publication_Date = the_list.Publication_Date.astype(int)

# %%
the_list[(the_list.Book_Title_Cleaned == 'unknown')]
# Out:
# Empty DataFrame
# Columns: [Fiction work(s), Film adaptation(s), Author, Book_Title, Publication_Date, Book_Title_Cleaned, Film_Title, Release_Date]
# Index: []

# %%
the_list.to_csv('../data/the_list.csv')

# %%
list_raw.Release_Date.min()
# Out:
# '1905'

# %%
corr_list = list_raw[['Release_Date', 'Publication_Date']]

# %%
corr_list = corr_list[~(corr_list.Publication_Date == 'unknown')]
corr_list = corr_list[~(corr_list.Release_Date == 'unknown')]

# %%
corr_list.Publication_Date = corr_list.Publication_Date.astype(int)
corr_list.Release_Date = corr_list.Release_Date.astype(int)

# %%
corr_list['time_to_adapt'] = corr_list.Release_Date - corr_list.Publication_Date

# %%
corr_list.corr(numeric_only = True)
# Out:
#                   Release_Date  Publication_Date  time_to_adapt
# Release_Date          1.000000          0.264318       0.175938
# Publication_Date      0.264318          1.000000      -0.902888
# time_to_adapt         0.175938         -0.902888       1.000000

# %%
color_palette = {'background': '#4a4a4a', 
                 'imdb': '#f5c518', 
                 'goodreads': '#e9e5cd', 
                 'gross': '#7FB184', 
                 'lines': '#FFFFFF'}

# %%
fig, ax = plt.subplots()
fig.patch.set_facecolor(color_palette['background'])
corr_list.plot(x='Publication_Date', y='time_to_adapt', kind = 'scatter', color = color_palette['lines'], figsize=(12, 6), legend=False, ax=ax)
plt.title('Publication Date Vs. Time to Adapt', fontsize = 18, color =  color_palette['lines'])
ax.set_facecolor(color_palette['background'])
plt.xlabel('Publication Date', color =  color_palette['lines'], fontsize = 14)
plt.ylabel('Time to Adapt', color =  color_palette['lines'], fontsize = 14)
ax.spines[["bottom","left","top","right"]].set_color(color_palette['lines'])
ax.set_yticklabels(ax.get_yticklabels(), ha='right', va='center', fontsize = 14, color =  color_palette['lines'])
ax.set_xticklabels(ax.get_xticklabels(), fontsize = 14)
ax.tick_params(axis='y', pad=5, color =  color_palette['lines'])
ax.tick_params(axis='x', color =  color_palette['lines'], labelcolor=color_palette['lines'])
plt.tight_layout();
plt.savefig("../images/Publication_Date_Vs_Time_to_Adapt.png", dpi=300, bbox_inches='tight')
# Out:
# C:\Users\erics\AppData\Local\Temp\ipykernel_32080\90962237.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), ha='right', va='center', fontsize = 14, color =  color_palette['lines'])
# C:\Users\erics\AppData\Local\Temp\ipykernel_32080\90962237.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize = 14)

# %%
corr_list2 = corr_list[corr_list.Publication_Date >= 1900]

# %%
fig, ax = plt.subplots()
fig.patch.set_facecolor(color_palette['background'])
corr_list2.plot(x='Publication_Date', y='time_to_adapt', kind = 'scatter', color = color_palette['lines'], figsize=(12, 6), legend=False, ax=ax)
plt.title('Publication Date Vs. Time to Adapt', fontsize = 18, color =  color_palette['lines'])
ax.set_facecolor(color_palette['background'])
plt.xlabel('Publication Date', color =  color_palette['lines'], fontsize = 14)
plt.ylabel('Time to Adapt', color =  color_palette['lines'], fontsize = 14)
ax.spines[["bottom","left","top","right"]].set_color(color_palette['lines'])
ax.set_yticklabels(ax.get_yticklabels(), ha='right', va='center', fontsize = 14, color =  color_palette['lines'])
ax.set_xticklabels(ax.get_xticklabels(), fontsize = 14)
ax.tick_params(axis='y', pad=5, color =  color_palette['lines'])
ax.tick_params(axis='x', color =  color_palette['lines'], labelcolor=color_palette['lines'])
plt.tight_layout();
# Out:
# C:\Users\erics\AppData\Local\Temp\ipykernel_32080\2365052481.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), ha='right', va='center', fontsize = 14, color =  color_palette['lines'])
# C:\Users\erics\AppData\Local\Temp\ipykernel_32080\2365052481.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize = 14)

# %%
corr_list2.corr(numeric_only = True)
# Out:
#                   Release_Date  Publication_Date  time_to_adapt
# Release_Date          1.000000          0.583893       0.356896
# Publication_Date      0.583893          1.000000      -0.549978
# time_to_adapt         0.356896         -0.549978       1.000000

# %%
ax = corr_list2.groupby('Release_Date').Publication_Date.count().plot(kind='line')

plt.show()

# %%
ax = corr_list2.groupby('Release_Date').time_to_adapt.mean().plot(kind='line')

plt.show()

# %%
ax = corr_list2.groupby('Publication_Date').time_to_adapt.mean().plot(kind='line')

plt.show()
